# %%
from energy_model import *

# %%
data = {
    'nA': 8, 'nK': 3, 'nT': 4,

    'alpha': 1/3, 'beta': 1/3, 'gamma': 1/3,
    'delta': 0.5,

    # K
    'C': [50.0, 50.0, 50.0],
    
    # K
    'G': [25.0, 25.0, 25.0],

    # K x T
    'c': [
        [1.2, 1.4, 1.4, 1, 1.2],
        [1.0, 1.1, 1.2, 1, 1.0],
        [1.0, 1.1, 1.2, 1, 1.0],
    ],

    # A x T
    'd': [
        [15.0, 18.0, 15.0, 15.0],
        [30.0, 12.0, 12.0, 42.0],
        [15.0, 12.0, 13.0, 14.5],
        [30.0, 16.0, 15.0, 15.0],
        [12.0, 22.0, 22.0, 34.0],
        [12.0, 15.0, 15.0, 15.0],
        [12.0, 34.0, 34.0, 3.0],
        [10.0, 15.0, 15.0, 2.0]
    ],

    # K x T
    'e': [
        [10.0, 10.0, 10.0, 10.0, 10.0],
        [10.0, 10.0, 10.0, 10.0, 10.0],
        [10.0, 10.0, 10.0, 10.0, 10.0]
    ],

    # K x K
    'l': [
        [0.0, 20.0, 40.0],
        [20.0, 0.0, 20.0],
        [40.0, 20.0, 0.0]
    ],

    # A x K
    'm': [
        [10.0, 20.0, 30.0],
        [15.0, 20.0, 25.0],
        [25.0, 20.0, 15.0],
        [30.0, 20.0, 10.0],
        [10.0, 20.0, 30.0],
        [15.0, 20.0, 25.0],
        [25.0, 20.0, 15.0],
        [30.0, 20.0, 10.0]
    ]
}

# %%
result = convert_result(run_instance(data), data['nA'], data['nK'], data['nT'])
print(show_result(result, data))
# Out:
# Status: OPTIMAL
# Objective Value: 3625.03
#
# Initial Batteries Charge: 12.5 (50.0%)
#
# TIME 1
#
#   FACILITY K0:
#     Energy Used:          49.0
#     Facility Capacity:    50.0
#     Energy Produced:      10.0
#     Purchased Energy (€): 51.5 (61.8)
#     Battery Charge:       25.0 / 25.0
#     AP connected (Energy Used):
# 	A2 (15.0)
# 	A4 (12.0)
# 	A5 (12.0)
# 	A7 (10.0)
#
#   FACILITY K1:
#     Energy Used:          45.0
#     Facility Capacity:    50.0
#     Energy Produced:      10.0
#     Purchased Energy (€): 47.5 (47.5)
#     Battery Charge:       25.0 / 25.0
#     AP connected (Energy Used):
# 	A0 (15.0)
# 	A1 (30.0)
#
#   FACILITY K2:
#     Energy Used:          42.0
#     Facility Capacity:    50.0
#     Energy Produced:      10.0
#     Purchased Energy (€): 44.5 (44.5)
#     Battery Charge:       25.0 / 25.0
#     AP connected (Energy Used):
# 	A3 (30.0)
# 	A6 (12.0)
#
# TIME 2
#
#   FACILITY K0:
#     Energy Used:          49.0
#     Facility Capacity:    50.0
#     Energy Produced:      10.0
#     Purchased Energy (€): 39.0 (54.6)
#     Battery Charge:       25.0 / 25.0
#     AP connected (Energy Used):
# 	A2 (12.0)
# 	A4 (22.0)
# 	A5 (15.0)
#
#   FACILITY K1:
#     Energy Used:          45.0
#     Facility Capacity:    50.0
#     Energy Produced:      10.0
#     Purchased Energy (€): 35.0 (38.5)
#     Battery Charge:       25.0 / 25.0
#     AP connected (Energy Used):
# 	A0 (18.0)
# 	A1 (12.0)
# 	A7 (15.0) +
#
#   FACILITY K2:
#     Energy Used:          50.0
#     Facility Capacity:    50.0
#     Energy Produced:      10.0
#     Purchased Energy (€): 40.0 (44.0)
#     Battery Charge:       25.0 / 25.0
#     AP connected (Energy Used):
# 	A3 (16.0)
# 	A6 (34.0)
#
# TIME 3
#
#   FACILITY K0:
#     Energy Used:          50.0
#     Facility Capacity:    50.0
#     Energy Produced:      10.0
#     Purchased Energy (€): 15.0 (21.0)
#     Battery Charge:       0.0 / 25.0
#     AP connected (Energy Used):
# 	A2 (13.0)
# 	A4 (22.0)
# 	A5 (15.0)
#
#   FACILITY K1:
#     Energy Used:          42.0
#     Facility Capacity:    50.0
#     Energy Produced:      10.0
#     Purchased Energy (€): 7.0 (8.4)
#     Battery Charge:       0.0 / 25.0
#     AP connected (Energy Used):
# 	A0 (15.0)
# 	A1 (12.0)
# 	A7 (15.0)
#
#   FACILITY K2:
#     Energy Used:          49.0
#     Facility Capacity:    50.0
#     Energy Produced:      10.0
#     Purchased Energy (€): 14.0 (16.8)
#     Battery Charge:       0.0 / 25.0
#     AP connected (Energy Used):
# 	A3 (15.0)
# 	A6 (34.0)
#
# TIME 4
#
#   FACILITY K0:
#     Energy Used:          49.0
#     Facility Capacity:    50.0
#     Energy Produced:      10.0
#     Purchased Energy (€): 39.0 (39.0)
#     Battery Charge:       0.0 / 25.0
#     AP connected (Energy Used):
# 	A4 (34.0)
# 	A5 (15.0)
#
#   FACILITY K1:
#     Energy Used:          44.0
#     Facility Capacity:    50.0
#     Energy Produced:      10.0
#     Purchased Energy (€): 34.0 (34.0)
#     Battery Charge:       0.0 / 25.0
#     AP connected (Energy Used):
# 	A1 (42.0)
# 	A7 (2.0)
#
#   FACILITY K2:
#     Energy Used:          47.5
#     Facility Capacity:    50.0
#     Energy Produced:      10.0
#     Purchased Energy (€): 37.5 (37.5)
#     Battery Charge:       0.0 / 25.0
#     AP connected (Energy Used):
# 	A0 (15.0) +
# 	A2 (14.5) +
# 	A3 (15.0)
# 	A6 (3.0)
#
# Total Energy Cost: 447.6
